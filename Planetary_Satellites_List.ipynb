# %%
[
    # Satellites of Earth
    {
        'Satellite': 'Moon',
        'Planet': 'Earth',
        'GM (km³/s²)': '4902.800±0.001',
        'Mean Radius (km)': '1737.4±0.1',
        'Mean Density (g/cm³)': '3.344±0.001'
    },
    # Satellites of Mars
    {
        'Satellite': 'Phobos',
        'Planet': 'Mars',
        'GM (km³/s²)': '0.0007087±0.0000006',
        'Mean Radius (km)': '11.08±0.04',
        'Mean Density (g/cm³)': '1.872±0.076'
    },
    {
        'Satellite': 'Deimos',
        'Planet': 'Mars',
        'GM (km³/s²)': '0.0000962±0.0000028',
        'Mean Radius (km)': '6.2±0.24',
        'Mean Density (g/cm³)': '1.471±0.166'
    },
    # Satellites of Jupiter
    {
        'Satellite': 'Io',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '5959.91547±0.00135',
        'Mean Radius (km)': '1821.49±0.50',
        'Mean Density (g/cm³)': '3.5276±0.0029'
    },
    {
        'Satellite': 'Europa',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '3202.71210±0.00181',
        'Mean Radius (km)': '1560.80±0.30',
        'Mean Density (g/cm³)': '3.0130±0.0017'
    },
    {
        'Satellite': 'Ganymede',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '9887.83275±0.00247',
        'Mean Radius (km)': '2631.20±1.70',
        'Mean Density (g/cm³)': '1.9416±0.0038'
    },
    {
        'Satellite': 'Callisto',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '7179.28340±0.00324',
        'Mean Radius (km)': '2410.30±1.50',
        'Mean Density (g/cm³)': '1.8340±0.0034'
    },
    {
        'Satellite': 'Amalthea',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '0.16456±0.00867',
        'Mean Radius (km)': '83.50±3.00',
        'Mean Density (g/cm³)': '1.0111±0.1213'
    },
    {
        'Satellite': 'Thebe',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '0.03015±0.01250',
        'Mean Radius (km)': '49.30±4.00',
        'Mean Density (g/cm³)': '0.9000±0.4327'
    },
    {
        'Satellite': 'Adrastea',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '0.00014±0.00020',
        'Mean Radius (km)': '8.20±4.00',
        'Mean Density (g/cm³)': '0.9018±1.8507'
    },
    {
        'Satellite': 'Metis',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '0.00250±0.00160',
        'Mean Radius (km)': '21.50±4.00',
        'Mean Density (g/cm³)': '0.9002±0.7642'
    },
    {
        'Satellite': 'Himalia',
        'Planet': 'Jupiter',
        'GM (km³/s²)': '0.15155±0.05763',
        'Mean Radius (km)': '85.00±10.00',
        'Mean Density (g/cm³)': '0.8827±0.4580'
    },
    # Satellites of Saturn
    {
        'Satellite': 'Mimas',
        'Planet': 'Saturn',
        'GM (km³/s²)': '2.50349±0.00014',
        'Mean Radius (km)': '198.20±0.40',
        'Mean Density (g/cm³)': '1.1501±0.0070'
    },
    {
        'Satellite': 'Enceladus',
        'Planet': 'Saturn',
        'GM (km³/s²)': '7.21037±0.00009',
        'Mean Radius (km)': '252.10±0.20',
        'Mean Density (g/cm³)': '1.6097±0.0038'
    },
    {
        'Satellite': 'Tethys',
        'Planet': 'Saturn',
        'GM (km³/s²)': '41.21353±0.00031',
        'Mean Radius (km)': '531.10±0.60',
        'Mean Density (g/cm³)': '0.9840±0.0033'
    },
    {
        'Satellite': 'Dione',
        'Planet': 'Saturn',
        'GM (km³/s²)': '73.11607±0.00005',
        'Mean Radius (km)': '561.40±0.40',
        'Mean Density (g/cm³)': '1.4781±0.0032'
    },
    {
        'Satellite': 'Rhea',
        'Planet': 'Saturn',
        'GM (km³/s²)': '153.94175±0.00041',
        'Mean Radius (km)': '763.50±0.60',
        'Mean Density (g/cm³)': '1.2372±0.0029'
    },
    {
        'Satellite': 'Titan',
        'Planet': 'Saturn',
        'GM (km³/s²)': '8978.13710±0.00025',
        'Mean Radius (km)': '2574.76±0.02',
        'Mean Density (g/cm³)': '1.8814±0.0001'
    },
    {
        'Satellite': 'Hyperion',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.37049±0.00005',
        'Mean Radius (km)': '135.00±4.00',
        'Mean Density (g/cm³)': '0.5386±0.0479'
    },
    {
        'Satellite': 'Iapetus',
        'Planet': 'Saturn',
        'GM (km³/s²)': '120.51511±0.00242',
        'Mean Radius (km)': '734.30±2.80',
        'Mean Density (g/cm³)': '1.0887±0.0125'
    },
    {
        'Satellite': 'Phoebe',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.55479±0.00108',
        'Mean Radius (km)': '106.50±0.70',
        'Mean Density (g/cm³)': '1.6428±0.0326'
    },
    {
        'Satellite': 'Janus',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.12662±0.00007',
        'Mean Radius (km)': '89.2±0.8',
        'Mean Density (g/cm³)': '0.6381±0.0172'
    },
    {
        'Satellite': 'Epimetheus',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.03514±0.00002',
        'Mean Radius (km)': '58.2±1.2',
        'Mean Density (g/cm³)': '0.6375±0.0394'
    },
    {
        'Satellite': 'Helene',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.00048±0.00002',
        'Mean Radius (km)': '18.00±0.40',
        'Mean Density (g/cm³)': '0.2918±0.0217'
    },
    {
        'Satellite': 'Atlas',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.00037±0.00001',
        'Mean Radius (km)': '15.1±0.8',
        'Mean Density (g/cm³)': '0.3850±0.0613'
    },
    {
        'Satellite': 'Prometheus',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.01071±0.00001',
        'Mean Radius (km)': '43.1±1.2',
        'Mean Density (g/cm³)': '0.4784±0.0400'
    },
    {
        'Satellite': 'Pandora',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.00926±0.00002',
        'Mean Radius (km)': '40.6±1.5',
        'Mean Density (g/cm³)': '0.4948±0.0549'
    },
    {
        'Satellite': 'Pan',
        'Planet': 'Saturn',
        'GM (km³/s²)': '0.00028±0.00014',
        'Mean Radius (km)': '14.0±1.2',
        'Mean Density (g/cm³)': '0.3650±0.2052'
    },
    # Satellites of Uranus
    {
        'Satellite': 'Ariel',
        'Planet': 'Uranus',
        'GM (km³/s²)': '83.5±1.4',
        'Mean Radius (km)': '578.9±0.6',
        'Mean Density (g/cm³)': '1.539±0.026'
    },
    {
        'Satellite': 'Umbriel',
        'Planet': 'Uranus',
        'GM (km³/s²)': '85.1±1.9',
        'Mean Radius (km)': '584.7±2.8',
        'Mean Density (g/cm³)': '1.523±0.041'
    },
    {
        'Satellite': 'Titania',
        'Planet': 'Uranus',
        'GM (km³/s²)': '226.9±4.1',
        'Mean Radius (km)': '788.9±1.8',
        'Mean Density (g/cm³)': '1.653±0.032'
    },
    {
        'Satellite': 'Oberon',
        'Planet': 'Uranus',
        'GM (km³/s²)': '205.3±5.8',
        'Mean Radius (km)': '761.4±2.6',
        'Mean Density (g/cm³)': '1.664±0.050'
    },
    {
        'Satellite': 'Miranda',
        'Planet': 'Uranus',
        'GM (km³/s²)': '4.3±0.2',
        'Mean Radius (km)': '235.8±0.7',
        'Mean Density (g/cm³)': '1.178±0.053'
    },
    # Satellites of Neptune
    {
        'Satellite': 'Triton',
        'Planet': 'Neptune',
        'GM (km³/s²)': '1428.49546±0.61603',
        'Mean Radius (km)': '1352.60±2.40',
        'Mean Density (g/cm³)': '2.0649±0.0110'
    },
    {
        'Satellite': 'Nereid',
        'Planet': 'Neptune',
        'GM (km³/s²)': '0.00000±0.0000',
        'Mean Radius (km)': '170.00±25.00',
        'Mean Density (g/cm³)': 'n/a'
    },
    {
        'Satellite': 'Naiad',
        'Planet': 'Neptune',
        'GM (km³/s²)': '0.00853±0.00480',
        'Mean Radius (km)': '29.00±6.00',
        'Mean Density (g/cm³)': '1.2511±1.0478'
    },
    {
        'Satellite': 'Thalassa',
        'Planet': 'Neptune',
        'GM (km³/s²)': '0.02359±0.00522',
        'Mean Radius (km)': '40.00±8.00',
        'Mean Density (g/cm³)': '1.3184±0.8432'
    },
    {
        'Satellite': 'Despina',
        'Planet': 'Neptune',
        'GM (km³/s²)': '0.11673±0.25263',
        'Mean Radius (km)': '74.00±10.00',
        'Mean Density (g/cm³)': '1.0304±2.2689'
    },
    {
        'Satellite': 'Galatea',
        'Planet': 'Neptune',
        'GM (km³/s²)': '0.18990±0.76278',
        'Mean Radius (km)': '79.00±12.00',
        'Mean Density (g/cm³)': '1.377±5.5695'
    },
    {
        'Satellite': 'Larissa',
        'Planet': 'Neptune',
        'GM (km³/s²)': '0.25484±3.12230',
        'Mean Radius (km)': '96.00±7.00',
        'Mean Density (g/cm³)': '1.0303±12.626'
    },
    {
        'Satellite': 'Proteus',
        'Planet': 'Neptune',
        'GM (km³/s²)': '2.58342±2.42070',
        'Mean Radius (km)': '208.00±8.00',
        'Mean Density (g/cm³)': '1.0269±0.9695'
    },
    # Satellites of Pluto
    {
        'Satellite': 'Charon',
        'Planet': 'Pluto',
        'GM (km³/s²)': '106.1±0.3',
        'Mean Radius (km)': '606.0±0.5',
        'Mean Density (g/cm³)': '1.853±0.004'
    },
    {
        'Satellite': 'Nix',
        'Planet': 'Pluto',
        'GM (km³/s²)': '0.0015±0.0005',
        'Mean Radius (km)': '18.0±1.0',
        'Mean Density (g/cm³)': '0.88±0.31'
    },
    {
        'Satellite': 'Hydra',
        'Planet': 'Pluto',
        'GM (km³/s²)': '0.0020±0.0003',
        'Mean Radius (km)': '18.5±1.0',
        'Mean Density (g/cm³)': '1.21±0.19'
    },
    {
        'Satellite': 'Kerberos',
        'Planet': 'Pluto',
        'GM (km³/s²)': '<0.0002',
        'Mean Radius (km)': '6.0±1.0',
        'Mean Density (g/cm³)': 'n/a'
    },
    {
        'Satellite': 'Styx',
        'Planet': 'Pluto',
        'GM (km³/s²)': '<0.0003',
        'Mean Radius (km)': '5.2±1.0',
        'Mean Density (g/cm³)': 'n/a'
    }
]
